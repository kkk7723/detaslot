# %%
from __future__ import annotations

import argparse
import importlib
import sqlite3
import sys
import time
from pathlib import Path
from typing import Any

import pandas as pd


# =========================================================
# プロジェクトルート設定
# =========================================================

def find_project_root(start_path: Path) -> Path:
    """
    config/、utils/、scripts/ が存在する場所を
    プロジェクトルートとして返す。
    """
    current = start_path.resolve()

    if current.is_file():
        current = current.parent

    for candidate in [current, *current.parents]:
        if (
            (candidate / "config").is_dir()
            and (candidate / "utils").is_dir()
            and (candidate / "scripts").is_dir()
        ):
            return candidate

    raise RuntimeError(
        "detaslotのプロジェクトルートを"
        f"特定できませんでした: {start_path}"
    )


if "__file__" in globals():
    # .py実行時
    PROJECT_ROOT = find_project_root(
        Path(__file__)
    )
else:
    # Notebook実行時
    PROJECT_ROOT = find_project_root(
        Path.cwd()
    )


if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(
        0,
        str(PROJECT_ROOT),
    )


print(
    f"[INFO] PROJECT_ROOT: "
    f"{PROJECT_ROOT}"
)
print(
    f"[INFO] config存在: "
    f"{(PROJECT_ROOT / 'config').is_dir()}"
)
print(
    f"[INFO] utils存在: "
    f"{(PROJECT_ROOT / 'utils').is_dir()}"
)


# =========================================================
# 共通設定
# =========================================================

from config.common import (
    DEFAULT_SITE,
    TABLE_NAME,
    require_file,
)


# ==================================================
# 店舗選択
# ==================================================

def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser()

    parser.add_argument(
        "--site",
        default=DEFAULT_SITE,
        help="config名",
    )

    return parser.parse_args()


if "__file__" in globals():
    # .py実行時
    # --site指定があればそれを使用し、
    # 指定がなければDEFAULT_SITEを使用
    args = parse_args()
else:
    # Notebook実行時
    args = argparse.Namespace(
        site=DEFAULT_SITE,
    )


config_file = (
    PROJECT_ROOT
    / "config"
    / f"{args.site}.py"
)

if not config_file.is_file():
    raise FileNotFoundError(
        f"店舗設定が見つかりません: {config_file}"
    )


try:
    site_config = importlib.import_module(
        f"config.{args.site}"
    )
except ModuleNotFoundError as exc:
    raise SystemExit(
        f"[ERROR] 店舗設定が見つかりません: "
        f"config/{args.site}.py"
    ) from exc


if not hasattr(site_config, "DB_PATH"):
    raise AttributeError(
        f"config/{args.site}.py に "
        "DB_PATH が設定されていません。"
    )


db_path = Path(
    site_config.DB_PATH
)


# SITE_PUBLIC_BASE_URLがあれば優先
public_base_url = str(
    getattr(
        site_config,
        "SITE_PUBLIC_BASE_URL",
        f"https://sedoinfinity.xsrv.jp/{args.site}",
    )
).rstrip("/")


machine_base_url = (
    f"{public_base_url}/machines"
)


print(f"[INFO] 対象店舗: {args.site}")
print(f"[INFO] 使用DB: {db_path}")
print(f"[INFO] 対象テーブル: {TABLE_NAME}")
print(
    f"[INFO] 台番号URL基準: "
    f"{machine_base_url}"
)


# =========================================================
# SQLite共通
# =========================================================

def quote_identifier(
    identifier: str,
) -> str:
    """
    SQLiteの識別子を[]で囲む。
    """
    return (
        "["
        + str(identifier).replace(
            "]",
            "]]",
        )
        + "]"
    )


def get_table_columns(
    connection: sqlite3.Connection,
    table_name: str,
) -> set[str]:
    """
    テーブルに存在するカラム名を取得する。
    """
    cursor = connection.execute(
        f"PRAGMA table_info("
        f"{quote_identifier(table_name)}"
        f")"
    )

    return {
        str(row[1])
        for row in cursor.fetchall()
    }


# =========================================================
# 台番号整形
# =========================================================

def normalize_machine_number(
    value: Any,
) -> str:
    """
    URLファイル名用に台番号を整形する。

    例:
        32     -> "32"
        "0032" -> "32"
        32.0   -> "32"
    """
    if value is None:
        return ""

    try:
        if pd.isna(value):
            return ""
    except (
        TypeError,
        ValueError,
    ):
        pass

    text = str(value).strip()

    if not text:
        return ""

    try:
        number = float(text)

        if number.is_integer():
            return str(
                int(number)
            )
    except ValueError:
        pass

    return text


def make_machine_url(
    machine_number: Any,
) -> str | None:
    """
    台番号詳細ページのURLを作成する。

    現在のページ構成:
        /machines/32.html
    """
    normalized = normalize_machine_number(
        machine_number
    )

    if not normalized:
        return None

    return (
        f"{machine_base_url}/"
        f"{normalized}.html"
    )


# =========================================================
# メイン処理
# =========================================================

def main() -> None:
    start_time = time.time()

    require_file(
        db_path,
        "店舗別SQLiteデータベース",
    )

    # -----------------------------------------------------
    # カラム確認
    # -----------------------------------------------------

    with sqlite3.connect(
        db_path
    ) as connection:
        table_columns = get_table_columns(
            connection,
            TABLE_NAME,
        )

    required_columns = [
        "実行日",
        "SKU",
        "台番号",
        "台番号URL",
    ]

    missing_columns = [
        column
        for column in required_columns
        if column not in table_columns
    ]

    if missing_columns:
        raise RuntimeError(
            f"{TABLE_NAME} に必要列がありません: "
            f"{missing_columns}"
        )

    print(
        "[DB] 必須カラム確認完了"
    )

    # -----------------------------------------------------
    # DB内の最新日取得
    # -----------------------------------------------------

    latest_date_sql = f"""
        SELECT
            MAX(
                date(
                    {quote_identifier("実行日")}
                )
            )
        FROM {quote_identifier(TABLE_NAME)}
        WHERE
            {quote_identifier("実行日")}
            IS NOT NULL
            AND TRIM(
                CAST(
                    {quote_identifier("実行日")}
                    AS TEXT
                )
            ) <> ''
    """

    with sqlite3.connect(
        db_path
    ) as connection:
        latest_date_row = connection.execute(
            latest_date_sql
        ).fetchone()

    latest_date = (
        latest_date_row[0]
        if latest_date_row
        else None
    )

    if not latest_date:
        print(
            "[INFO] 有効な実行日データがありません。"
        )
        return

    print(
        f"[DB] 最新日: "
        f"{latest_date}"
    )

    # -----------------------------------------------------
    # 最新日のレコード取得
    # -----------------------------------------------------

    select_sql = f"""
        SELECT
            ROWID AS _rowid,
            {quote_identifier("実行日")},
            {quote_identifier("SKU")},
            {quote_identifier("台番号")},
            {quote_identifier("台番号URL")}
                AS current_url
        FROM {quote_identifier(TABLE_NAME)}
        WHERE
            date(
                {quote_identifier("実行日")}
            ) = ?
        ORDER BY ROWID ASC
    """

    with sqlite3.connect(
        db_path
    ) as connection:
        dataframe = pd.read_sql_query(
            select_sql,
            connection,
            params=[
                latest_date,
            ],
        )

    if dataframe.empty:
        print(
            "[INFO] 最新日の対象データが"
            "ありません。"
        )
        return

    print(
        f"[DB] 対象レコード: "
        f"{len(dataframe)}件"
    )

    # -----------------------------------------------------
    # URL生成
    # -----------------------------------------------------

    dataframe[
        "new_url"
    ] = dataframe[
        "台番号"
    ].map(
        make_machine_url
    )

    generated_count = int(
        dataframe["new_url"]
        .notna()
        .sum()
    )

    print(
        f"[URL] 生成成功: "
        f"{generated_count}件"
    )

    # -----------------------------------------------------
    # 更新対象抽出
    # -----------------------------------------------------

    update_parameters: list[
        tuple[
            str | None,
            int,
        ]
    ] = []

    unchanged_count = 0
    invalid_count = 0

    for _, row in dataframe.iterrows():
        new_url = row["new_url"]

        current_url = (
            ""
            if pd.isna(row["current_url"])
            else str(
                row["current_url"]
            ).strip()
        )

        if not new_url:
            invalid_count += 1

            print(
                f"[SKIP] 台番号不正: "
                f"{row['台番号']!r}"
            )
            continue

        if current_url == new_url:
            unchanged_count += 1
            continue

        update_parameters.append((
            new_url,
            int(row["_rowid"]),
        ))

        print(
            f"[UPDATE準備] "
            f"台番号={row['台番号']}, "
            f"SKU={row['SKU']}, "
            f"URL={new_url}"
        )

    print(
        f"[DB] 変更なし: "
        f"{unchanged_count}件"
    )
    print(
        f"[DB] 台番号不正: "
        f"{invalid_count}件"
    )
    print(
        f"[DB] 更新対象: "
        f"{len(update_parameters)}件"
    )

    # -----------------------------------------------------
    # ROWID単位で更新
    # -----------------------------------------------------

    update_sql = f"""
        UPDATE {quote_identifier(TABLE_NAME)}
        SET
            {quote_identifier("台番号URL")}
            = ?
        WHERE
            ROWID = ?
    """

    updated_count = 0

    if update_parameters:
        with sqlite3.connect(
            db_path
        ) as connection:
            cursor = connection.cursor()

            cursor.executemany(
                update_sql,
                update_parameters,
            )

            connection.commit()

            updated_count = len(
                update_parameters
            )

    print(
        f"✅ 台番号URL更新完了: "
        f"{updated_count}件"
    )
    print(
        f"[DB] 対象日: "
        f"{latest_date}"
    )
    print(
        f"[INFO] 所要時間: "
        f"{time.time() - start_time:.2f}秒"
    )


# =========================================================
# 実行
# =========================================================

if __name__ == "__main__":
    main()
# Out:
# [INFO] PROJECT_ROOT: /home/ubuntu/myenv310/detaslot
# [INFO] config存在: True
# [INFO] utils存在: True
# [INFO] 対象店舗: gigaslot
# [INFO] 使用DB: /home/ubuntu/myenv310/detaslot/db/gigaslot/data.db
# [INFO] 対象テーブル: result_table
# [INFO] 台番号URL基準: https://sedoinfinity.xsrv.jp/gigaslot/machines
# [DB] 必須カラム確認完了
# [DB] 最新日: 2026-08-02
# [DB] 対象レコード: 95件
# [URL] 生成成功: 95件
# [UPDATE準備] 台番号=32, SKU=202608020001, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020002, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020003, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020004, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020005, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020006, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020007, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020008, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020009, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020010, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020011, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020012, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020013, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020014, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=32, SKU=202608020015, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/32.html
# [UPDATE準備] 台番号=33, SKU=202608020016, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/33.html
# [UPDATE準備] 台番号=34, SKU=202608020019, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/34.html
# [UPDATE準備] 台番号=35, SKU=202608020020, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/35.html
# [UPDATE準備] 台番号=36, SKU=202608020021, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/36.html
# [UPDATE準備] 台番号=123, SKU=202608020022, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/123.html
# [UPDATE準備] 台番号=124, SKU=202608020023, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/124.html
# [UPDATE準備] 台番号=125, SKU=202608020024, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/125.html
# [UPDATE準備] 台番号=126, SKU=202608020025, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/126.html
# [UPDATE準備] 台番号=127, SKU=202608020026, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/127.html
# [UPDATE準備] 台番号=128, SKU=202608020027, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/128.html
# [UPDATE準備] 台番号=129, SKU=202608020028, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/129.html
# [UPDATE準備] 台番号=130, SKU=202608020029, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/130.html
# [UPDATE準備] 台番号=131, SKU=202608020030, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/131.html
# [UPDATE準備] 台番号=132, SKU=202608020031, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/132.html
# [UPDATE準備] 台番号=133, SKU=202608020032, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/133.html
# [UPDATE準備] 台番号=134, SKU=202608020033, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/134.html
# [UPDATE準備] 台番号=135, SKU=202608020034, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/135.html
# [UPDATE準備] 台番号=136, SKU=202608020035, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/136.html
# [UPDATE準備] 台番号=137, SKU=202608020036, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/137.html
# [UPDATE準備] 台番号=138, SKU=202608020037, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/138.html
# [UPDATE準備] 台番号=139, SKU=202608020038, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/139.html
# [UPDATE準備] 台番号=140, SKU=202608020039, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/140.html
# [UPDATE準備] 台番号=141, SKU=202608020040, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/141.html
# [UPDATE準備] 台番号=142, SKU=202608020041, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/142.html
# [UPDATE準備] 台番号=143, SKU=202608020042, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/143.html
# [UPDATE準備] 台番号=144, SKU=202608020043, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/144.html
# [UPDATE準備] 台番号=145, SKU=202608020044, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/145.html
# [UPDATE準備] 台番号=146, SKU=202608020045, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/146.html
# [UPDATE準備] 台番号=147, SKU=202608020046, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/147.html
# [UPDATE準備] 台番号=148, SKU=202608020047, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/148.html
# [UPDATE準備] 台番号=149, SKU=202608020048, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/149.html
# [UPDATE準備] 台番号=150, SKU=202608020049, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/150.html
# [UPDATE準備] 台番号=151, SKU=202608020050, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/151.html
# [UPDATE準備] 台番号=152, SKU=202608020051, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/152.html
# [UPDATE準備] 台番号=153, SKU=202608020052, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/153.html
# [UPDATE準備] 台番号=154, SKU=202608020053, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/154.html
# [UPDATE準備] 台番号=155, SKU=202608020054, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/155.html
# [UPDATE準備] 台番号=156, SKU=202608020055, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/156.html
# [UPDATE準備] 台番号=157, SKU=202608020056, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/157.html
# [UPDATE準備] 台番号=158, SKU=202608020057, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/158.html
# [UPDATE準備] 台番号=159, SKU=202608020058, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/159.html
# [UPDATE準備] 台番号=160, SKU=202608020059, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/160.html
# [UPDATE準備] 台番号=161, SKU=202608020060, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/161.html
# [UPDATE準備] 台番号=162, SKU=202608020061, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/162.html
# [UPDATE準備] 台番号=163, SKU=202608020062, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/163.html
# [UPDATE準備] 台番号=164, SKU=202608020063, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/164.html
# [UPDATE準備] 台番号=165, SKU=202608020064, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/165.html
# [UPDATE準備] 台番号=166, SKU=202608020065, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/166.html
# [UPDATE準備] 台番号=167, SKU=202608020066, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/167.html
# [UPDATE準備] 台番号=168, SKU=202608020067, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/168.html
# [UPDATE準備] 台番号=169, SKU=202608020068, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/169.html
# [UPDATE準備] 台番号=170, SKU=202608020069, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/170.html
# [UPDATE準備] 台番号=171, SKU=202608020070, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/171.html
# [UPDATE準備] 台番号=172, SKU=202608020071, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/172.html
# [UPDATE準備] 台番号=173, SKU=202608020072, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/173.html
# [UPDATE準備] 台番号=174, SKU=202608020073, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/174.html
# [UPDATE準備] 台番号=175, SKU=202608020074, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/175.html
# [UPDATE準備] 台番号=176, SKU=202608020075, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/176.html
# [UPDATE準備] 台番号=177, SKU=202608020076, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/177.html
# [UPDATE準備] 台番号=178, SKU=202608020077, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/178.html
# [UPDATE準備] 台番号=179, SKU=202608020078, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/179.html
# [UPDATE準備] 台番号=180, SKU=202608020079, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/180.html
# [UPDATE準備] 台番号=181, SKU=202608020080, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/181.html
# [UPDATE準備] 台番号=182, SKU=202608020081, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/182.html
# [UPDATE準備] 台番号=183, SKU=202608020082, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/183.html
# [UPDATE準備] 台番号=184, SKU=202608020083, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/184.html
# [UPDATE準備] 台番号=185, SKU=202608020084, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/185.html
# [UPDATE準備] 台番号=186, SKU=202608020085, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/186.html
# [UPDATE準備] 台番号=187, SKU=202608020086, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/187.html
# [UPDATE準備] 台番号=189, SKU=202608020088, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/189.html
# [UPDATE準備] 台番号=190, SKU=202608020089, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/190.html
# [UPDATE準備] 台番号=191, SKU=202608020090, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/191.html
# [UPDATE準備] 台番号=192, SKU=202608020091, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/192.html
# [UPDATE準備] 台番号=193, SKU=202608020092, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/193.html
# [UPDATE準備] 台番号=194, SKU=202608020093, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/194.html
# [UPDATE準備] 台番号=195, SKU=202608020094, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/195.html
# [UPDATE準備] 台番号=196, SKU=202608020095, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/196.html
# [UPDATE準備] 台番号=37, SKU=202608020096, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/37.html
# [UPDATE準備] 台番号=38, SKU=202608020097, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/38.html
# [UPDATE準備] 台番号=39, SKU=202608020098, URL=https://sedoinfinity.xsrv.jp/gigaslot/machines/39.html
# [DB] 変更なし: 0件
# [DB] 台番号不正: 0件
# [DB] 更新対象: 95件
# ✅ 台番号URL更新完了: 95件
# [DB] 対象日: 2026-08-02
# [INFO] 所要時間: 0.10秒
