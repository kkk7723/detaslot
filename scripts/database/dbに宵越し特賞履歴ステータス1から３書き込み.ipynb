# %%
from __future__ import annotations

import argparse
import importlib
import sqlite3
import sys
import time
from pathlib import Path
from typing import Any

import pandas as pd


# =========================================================
# プロジェクトルート設定
# =========================================================

def find_project_root(
    start_path: Path,
) -> Path:
    """
    config/ と utils/ が存在するディレクトリを
    detaslotのプロジェクトルートとして返す。
    """
    current = start_path.resolve()

    if current.is_file():
        current = current.parent

    for candidate in [
        current,
        *current.parents,
    ]:
        if (
            (candidate / "config").is_dir()
            and (candidate / "utils").is_dir()
        ):
            return candidate

    raise RuntimeError(
        "detaslotのプロジェクトルートを"
        "特定できませんでした。"
        f" 開始位置: {start_path}"
    )


if "__file__" in globals():
    # scripts/database/*.py から実行
    PROJECT_ROOT = find_project_root(
        Path(__file__)
    )
else:
    # scripts/database/*.ipynb から実行
    PROJECT_ROOT = find_project_root(
        Path.cwd()
    )


if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(
        0,
        str(PROJECT_ROOT),
    )


print(
    f"[INFO] PROJECT_ROOT: "
    f"{PROJECT_ROOT}"
)
print(
    f"[INFO] config存在: "
    f"{(PROJECT_ROOT / 'config').is_dir()}"
)
print(
    f"[INFO] utils存在: "
    f"{(PROJECT_ROOT / 'utils').is_dir()}"
)


# =========================================================
# 共通設定
# =========================================================

from config.common import (
    DEFAULT_SITE,
    TABLE_NAME,
    require_file,
)


# ==================================================
# 店舗選択
# ==================================================

def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser()

    parser.add_argument(
        "--site",
        default=DEFAULT_SITE,
        help="config名",
    )

    return parser.parse_args()


if "__file__" in globals():
    # .py実行時
    # --site指定があればそれを使用し、
    # 指定がなければDEFAULT_SITEを使用
    args = parse_args()
else:
    # Notebook実行時
    args = argparse.Namespace(
        site=DEFAULT_SITE,
    )


config_file = (
    PROJECT_ROOT
    / "config"
    / f"{args.site}.py"
)

if not config_file.is_file():
    raise FileNotFoundError(
        f"店舗設定が見つかりません: {config_file}"
    )



try:
    site_config = importlib.import_module(
        f"config.{args.site}"
    )
except ModuleNotFoundError as exc:
    raise SystemExit(
        f"[ERROR] 店舗設定が見つかりません: "
        f"config/{args.site}.py"
    ) from exc


if not hasattr(site_config, "DB_PATH"):
    raise AttributeError(
        f"config/{args.site}.py に "
        "DB_PATH が設定されていません。"
    )


db_path = Path(site_config.DB_PATH)

print(f"[INFO] 対象店舗: {args.site}")
print(f"[INFO] 使用DB: {db_path}")
print(f"[INFO] 対象テーブル: {TABLE_NAME}")


# =========================================================
# 対象カラム
# =========================================================

SOURCE_COLUMNS = [
    "実行日",
    "台番号",
    "BIG",
    "REG",
    "BONUS",
    "ATART",
    "ステータス1回前",
    "ステータス2回前",
    "ステータス3回前",
]

DESTINATION_COLUMNS = [
    "宵越し特賞履歴ステータス1回前",
    "宵越し特賞履歴ステータス2回前",
    "宵越し特賞履歴ステータス3回前",
]


# =========================================================
# 共通関数
# =========================================================

def quote_identifier(
    identifier: str,
) -> str:
    """
    SQLiteのテーブル名・カラム名を
    []で囲む。
    """
    return (
        "["
        + str(identifier).replace(
            "]",
            "]]",
        )
        + "]"
    )


def get_table_columns(
    connection: sqlite3.Connection,
    table_name: str,
) -> set[str]:
    """
    SQLiteテーブルに存在するカラム名を取得する。
    """
    cursor = connection.execute(
        f"PRAGMA table_info("
        f"{quote_identifier(table_name)}"
        f")"
    )

    return {
        str(row[1])
        for row in cursor.fetchall()
    }


def require_columns(
    existing_columns: set[str],
    required_columns: list[str],
) -> None:
    """
    必須カラムの存在を確認する。
    """
    missing_columns = [
        column
        for column in required_columns
        if column not in existing_columns
    ]

    if missing_columns:
        raise RuntimeError(
            f"{TABLE_NAME} に必要列がありません: "
            f"{missing_columns}"
        )


def normalize_machine_number(
    value: Any,
) -> str:
    """
    台番号をグループ化用の形式へ統一する。

    例:
        32     -> "32"
        "0032" -> "32"
        32.0   -> "32"
        空欄   -> ""
    """
    if value is None:
        return ""

    try:
        if pd.isna(value):
            return ""
    except (TypeError, ValueError):
        pass

    text = str(value).strip()

    if not text:
        return ""

    try:
        number = float(text)

        if number.is_integer():
            return str(int(number))
    except ValueError:
        pass

    if text.isdigit():
        return str(int(text))

    return text


def clean_status(
    value: Any,
) -> str | None:
    """
    ステータス値を保存用に整形する。
    """
    if value is None:
        return None

    try:
        if pd.isna(value):
            return None
    except (TypeError, ValueError):
        pass

    text = str(value).strip()

    return text if text else None


def pick_previous_statuses_at_first_hit(
    machine_dataframe: pd.DataFrame,
) -> tuple[
    str | None,
    str | None,
    str | None,
]:
    """
    1台分のデータを最新から過去へ並べる。

    BIG・REG・BONUS・ATARTのいずれかが
    1以上になった最初のレコードから、

    - ステータス1回前
    - ステータス2回前
    - ステータス3回前

    を取得して返す。

    ヒットがない場合は、
    (None, None, None) を返す。
    """
    working = (
        machine_dataframe
        .sort_values(
            [
                "実行日",
                "_rowid",
            ],
            ascending=[
                False,
                False,
            ],
        )
        .reset_index(drop=True)
        .copy()
    )

    hit_mask = (
        (working["BIG"] >= 1)
        | (working["REG"] >= 1)
        | (working["BONUS"] >= 1)
        | (working["ATART"] >= 1)
    )

    hit_positions = working.index[
        hit_mask
    ].tolist()

    if not hit_positions:
        return (
            None,
            None,
            None,
        )

    first_hit_position = hit_positions[0]

    hit_row = working.iloc[
        first_hit_position
    ]

    return (
        clean_status(
            hit_row[
                "ステータス1回前"
            ]
        ),
        clean_status(
            hit_row[
                "ステータス2回前"
            ]
        ),
        clean_status(
            hit_row[
                "ステータス3回前"
            ]
        ),
    )


# =========================================================
# メイン処理
# =========================================================

def main() -> None:
    start_time = time.time()

    require_file(
        db_path,
        "店舗別SQLiteデータベース",
    )

    # -----------------------------------------------------
    # DBカラム確認
    # -----------------------------------------------------

    with sqlite3.connect(
        db_path
    ) as connection:
        table_columns = get_table_columns(
            connection,
            TABLE_NAME,
        )

    require_columns(
        table_columns,
        [
            *SOURCE_COLUMNS,
            *DESTINATION_COLUMNS,
        ],
    )

    print(
        f"[DB] 必須カラム確認完了: "
        f"{len(SOURCE_COLUMNS) + len(DESTINATION_COLUMNS)}列"
    )

    # -----------------------------------------------------
    # DBデータ取得
    # -----------------------------------------------------

    select_columns = ", ".join(
        quote_identifier(column)
        for column in SOURCE_COLUMNS
    )

    sql = f"""
        SELECT
            ROWID AS _rowid,
            {select_columns}
        FROM {quote_identifier(TABLE_NAME)}
        ORDER BY
            datetime(
                {quote_identifier("実行日")}
            ) DESC,
            ROWID DESC
    """

    with sqlite3.connect(
        db_path
    ) as connection:
        dataframe = pd.read_sql_query(
            sql,
            connection,
        )

    if dataframe.empty:
        print(
            "[INFO] DBに対象データがありません。"
        )
        return

    print(
        f"[DB] 取得完了: "
        f"{len(dataframe)}件"
    )

    # -----------------------------------------------------
    # 型整備
    # -----------------------------------------------------

    dataframe["実行日"] = pd.to_datetime(
        dataframe["実行日"],
        errors="coerce",
    )

    dataframe = dataframe.dropna(
        subset=[
            "実行日",
            "台番号",
        ],
    ).copy()

    dataframe[
        "照合用台番号"
    ] = dataframe[
        "台番号"
    ].map(
        normalize_machine_number
    )

    dataframe = dataframe[
        dataframe["照合用台番号"] != ""
    ].copy()

    if dataframe.empty:
        print(
            "[INFO] 有効な実行日・台番号を"
            "持つデータがありません。"
        )
        return

    numeric_columns = [
        "BIG",
        "REG",
        "BONUS",
        "ATART",
    ]

    for column in numeric_columns:
        dataframe[column] = pd.to_numeric(
            dataframe[column],
            errors="coerce",
        ).fillna(0).astype(int)

    # -----------------------------------------------------
    # DB内の最新日を取得
    # -----------------------------------------------------

    latest_date = (
        dataframe["実行日"]
        .dt.date
        .max()
    )

    latest_date_dataframe = dataframe[
        dataframe["実行日"].dt.date
        == latest_date
    ].copy()

    print(
        f"[DB] 最新日: "
        f"{latest_date}"
    )
    print(
        f"[DB] 最新日のレコード数: "
        f"{len(latest_date_dataframe)}件"
    )

    # -----------------------------------------------------
    # 最新日の各台について最新1レコードを取得
    # -----------------------------------------------------

    latest_rows = (
        latest_date_dataframe
        .sort_values(
            [
                "照合用台番号",
                "実行日",
                "_rowid",
            ],
            ascending=[
                True,
                False,
                False,
            ],
        )
        .drop_duplicates(
            subset=[
                "照合用台番号"
            ],
            keep="first",
        )
        .copy()
    )

    print(
        f"[DB] 最新日の対象台数: "
        f"{len(latest_rows)}台"
    )

    # -----------------------------------------------------
    # 台番号ごとの宵越しステータス計算
    # -----------------------------------------------------

    calculated_statuses: dict[
        str,
        tuple[
            str | None,
            str | None,
            str | None,
        ],
    ] = {}

    for (
        normalized_machine_number,
        machine_group,
    ) in dataframe.groupby(
        "照合用台番号",
        sort=False,
    ):
        statuses = (
            pick_previous_statuses_at_first_hit(
                machine_group
            )
        )

        calculated_statuses[
            normalized_machine_number
        ] = statuses

        print(
            f"[CALC] 台番号="
            f"{normalized_machine_number}, "
            f"1回前={statuses[0]!r}, "
            f"2回前={statuses[1]!r}, "
            f"3回前={statuses[2]!r}"
        )

    # -----------------------------------------------------
    # 最新日の各台の最新行だけ更新
    # -----------------------------------------------------

    update_sql = f"""
        UPDATE {quote_identifier(TABLE_NAME)}
        SET
            {
                quote_identifier(
                    DESTINATION_COLUMNS[0]
                )
            } = ?,
            {
                quote_identifier(
                    DESTINATION_COLUMNS[1]
                )
            } = ?,
            {
                quote_identifier(
                    DESTINATION_COLUMNS[2]
                )
            } = ?
        WHERE
            ROWID = ?
    """

    updates: list[
        tuple[
            str | None,
            str | None,
            str | None,
            int,
        ]
    ] = []

    for _, latest_row in latest_rows.iterrows():
        normalized_machine_number = str(
            latest_row["照合用台番号"]
        ).strip()

        statuses = calculated_statuses.get(
            normalized_machine_number,
            (
                None,
                None,
                None,
            ),
        )

        updates.append((
            statuses[0],
            statuses[1],
            statuses[2],
            int(latest_row["_rowid"]),
        ))

        print(
            f"[UPDATE準備] 台番号="
            f"{latest_row['台番号']}, "
            f"ROWID={latest_row['_rowid']}"
        )

    updated_count = 0

    with sqlite3.connect(
        db_path
    ) as connection:
        cursor = connection.cursor()

        for update_parameters in updates:
            cursor.execute(
                update_sql,
                update_parameters,
            )

            updated_count += max(
                cursor.rowcount,
                0,
            )

        connection.commit()

    # -----------------------------------------------------
    # 完了
    # -----------------------------------------------------

    print(
        "✅ 宵越し特賞履歴ステータス"
        "(1/2/3回前) 更新完了"
    )
    print(
        f"[DB] 更新行数: "
        f"{updated_count}行"
    )
    print(
        "[DB] 更新対象: "
        "最新日の各台の最新1レコードのみ"
    )
    print(
        f"[INFO] 所要時間: "
        f"{time.time() - start_time:.2f}秒"
    )


# =========================================================
# 実行
# =========================================================

if __name__ == "__main__":
    main()
# Out:
# [INFO] PROJECT_ROOT: /home/ubuntu/myenv310/detaslot
# [INFO] config存在: True
# [INFO] utils存在: True
# [INFO] 対象店舗: gigaslot
# [INFO] 使用DB: /home/ubuntu/myenv310/detaslot/db/gigaslot/data.db
# [INFO] 対象テーブル: result_table
# [DB] 必須カラム確認完了: 12列
# [DB] 取得完了: 70085件
# [DB] 最新日: 2026-08-02
# [DB] 最新日のレコード数: 19件
# [DB] 最新日の対象台数: 5台
# [CALC] 台番号=36, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=35, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=34, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=33, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=32, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=433, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=42, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=41, 1回前='REG', 2回前='AT/ART', 3回前='BIG'
# [CALC] 台番号=40, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=39, 1回前='AT/ART', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=38, 1回前='AT/ART', 2回前='BIG', 3回前='AT/ART'
# [CALC] 台番号=37, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=94, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=93, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=92, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=91, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=90, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=89, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=88, 1回前='AT/ART', 2回前=None, 3回前=None
# [CALC] 台番号=115, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=114, 1回前='AT/ART', 2回前=None, 3回前=None
# [CALC] 台番号=113, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=112, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=111, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=110, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=109, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=108, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=107, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=106, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=105, 1回前='BIG', 2回前='AT/ART', 3回前='BIG'
# [CALC] 台番号=104, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=103, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=102, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=101, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=100, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=99, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=98, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=97, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=96, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=95, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=196, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=178, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=177, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=176, 1回前='AT/ART', 2回前='REG', 3回前=None
# [CALC] 台番号=175, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=174, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=173, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=172, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=171, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=170, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=169, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=168, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=167, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=166, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=165, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=164, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=163, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=162, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=161, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=160, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=159, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=158, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=157, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=156, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=155, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=154, 1回前='REG', 2回前='REG', 3回前=None
# [CALC] 台番号=153, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=152, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=151, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=150, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=149, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=148, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=147, 1回前='REG', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=146, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=145, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=144, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=143, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=142, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=141, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=140, 1回前='AT/ART', 2回前='BIG', 3回前='AT/ART'
# [CALC] 台番号=139, 1回前='BIG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=138, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=137, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=136, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=135, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=134, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=133, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=132, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=131, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=130, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=129, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=128, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=127, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=126, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=125, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=124, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=123, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=122, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=121, 1回前='AT/ART', 2回前='AT/ART', 3回前='BIG'
# [CALC] 台番号=120, 1回前='AT/ART', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=119, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=118, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=117, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=116, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=209, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=208, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=207, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=206, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=205, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=204, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=203, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=202, 1回前='AT/ART', 2回前='AT/ART', 3回前=None
# [CALC] 台番号=201, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=200, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=199, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=198, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=197, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=195, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=194, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=193, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=192, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=191, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=190, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=189, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=188, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=187, 1回前='BIG', 2回前='REG', 3回前=None
# [CALC] 台番号=186, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=185, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=184, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=183, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=182, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=181, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=180, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=179, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=251, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=244, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=243, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=242, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=241, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=240, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=238, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=237, 1回前='REG', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=236, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=239, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=234, 1回前='AT/ART', 2回前='REG', 3回前=None
# [CALC] 台番号=233, 1回前=None, 2回前=None, 3回前=None
# [CALC] 台番号=232, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=231, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=230, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=229, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=228, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=227, 1回前='AT/ART', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=226, 1回前='AT/ART', 2回前='AT/ART', 3回前='BIG'
# [CALC] 台番号=225, 1回前='AT/ART', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=224, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=223, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=222, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=221, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=220, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=219, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=218, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=217, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=216, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=215, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=214, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=213, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=212, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=211, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=210, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=258, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=257, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=256, 1回前='AT/ART', 2回前='REG', 3回前=None
# [CALC] 台番号=255, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=254, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=253, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=252, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=250, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=249, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=248, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=247, 1回前='AT/ART', 2回前='REG', 3回前=None
# [CALC] 台番号=246, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=245, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=235, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=451, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=450, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=449, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=448, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=447, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=446, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=445, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=444, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=443, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=442, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=441, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=440, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=439, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=438, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=437, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=436, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=435, 1回前='BIG', 2回前='REG', 3回前=None
# [CALC] 台番号=434, 1回前='REG', 2回前=None, 3回前=None
# [CALC] 台番号=432, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=431, 1回前='REG', 2回前=None, 3回前=None
# [CALC] 台番号=430, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=429, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=428, 1回前='BIG', 2回前='BIG', 3回前=None
# [CALC] 台番号=427, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=426, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=425, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=424, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=423, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=422, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=421, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=420, 1回前='REG', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=419, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=418, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=417, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=416, 1回前='REG', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=415, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=414, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=413, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=412, 1回前='AT/ART', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=411, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=410, 1回前='AT/ART', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=409, 1回前='BIG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=408, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=407, 1回前='REG', 2回前=None, 3回前=None
# [CALC] 台番号=406, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=405, 1回前='BIG', 2回前='AT/ART', 3回前='BIG'
# [CALC] 台番号=404, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=403, 1回前='BIG', 2回前='AT/ART', 3回前='BIG'
# [CALC] 台番号=402, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=401, 1回前='BIG', 2回前='BIG', 3回前='AT/ART'
# [CALC] 台番号=400, 1回前='BIG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=399, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=398, 1回前='REG', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=397, 1回前='REG', 2回前=None, 3回前=None
# [CALC] 台番号=396, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=395, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=394, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=393, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=392, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=391, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=390, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=389, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=388, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=387, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=386, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=385, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=384, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=383, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=382, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=381, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=380, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=379, 1回前='AT/ART', 2回前=None, 3回前=None
# [CALC] 台番号=355, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=354, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=353, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=352, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=351, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=350, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=349, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=348, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=347, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=346, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=345, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=344, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=343, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=342, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=341, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=340, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=452, 1回前=None, 2回前=None, 3回前=None
# [CALC] 台番号=378, 1回前='REG', 2回前=None, 3回前=None
# [CALC] 台番号=377, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=376, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=375, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=374, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=373, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=372, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=371, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=370, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=369, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=368, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=367, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=366, 1回前='BIG', 2回前='REG', 3回前=None
# [CALC] 台番号=365, 1回前='REG', 2回前=None, 3回前=None
# [CALC] 台番号=364, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=363, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=362, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=361, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=360, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=359, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=358, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=357, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=356, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=339, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=338, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=337, 1回前='BIG', 2回前='BIG', 3回前=None
# [CALC] 台番号=336, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=335, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=334, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=333, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=332, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=331, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=330, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=329, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=328, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=327, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=326, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=325, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=324, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=323, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=322, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=321, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=320, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=319, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=318, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=317, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=316, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=315, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=314, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=313, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=312, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=311, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=310, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=309, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=308, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=307, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=306, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=305, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=304, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=303, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=302, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=301, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=300, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=299, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=298, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=297, 1回前='REG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=296, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=295, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=294, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=293, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=292, 1回前='REG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=291, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=290, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=289, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=288, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=287, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=286, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=285, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=284, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=283, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=282, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=281, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=280, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=279, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=278, 1回前='REG', 2回前='REG', 3回前=None
# [CALC] 台番号=277, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=276, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=275, 1回前='BIG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=274, 1回前='REG', 2回前='REG', 3回前='BIG'
# [CALC] 台番号=273, 1回前='BIG', 2回前='BIG', 3回前='BIG'
# [CALC] 台番号=272, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=271, 1回前='REG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=270, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=269, 1回前='BIG', 2回前='BIG', 3回前='REG'
# [CALC] 台番号=268, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=267, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=266, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=265, 1回前='BIG', 2回前='REG', 3回前='REG'
# [CALC] 台番号=264, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=263, 1回前='AT/ART', 2回前='AT/ART', 3回前='REG'
# [CALC] 台番号=262, 1回前='BIG', 2回前=None, 3回前=None
# [CALC] 台番号=261, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [CALC] 台番号=260, 1回前='AT/ART', 2回前='REG', 3回前='AT/ART'
# [CALC] 台番号=259, 1回前='AT/ART', 2回前='BIG', 3回前='AT/ART'
# [CALC] 台番号=推移グラフ, 1回前='AT/ART', 2回前='AT/ART', 3回前='AT/ART'
# [UPDATE準備] 台番号=32, ROWID=70081
# [UPDATE準備] 台番号=33, ROWID=70082
# [UPDATE準備] 台番号=34, ROWID=70083
# [UPDATE準備] 台番号=35, ROWID=70084
# [UPDATE準備] 台番号=36, ROWID=70085
# ✅ 宵越し特賞履歴ステータス(1/2/3回前) 更新完了
# [DB] 更新行数: 5行
# [DB] 更新対象: 最新日の各台の最新1レコードのみ
# [INFO] 所要時間: 1.16秒
