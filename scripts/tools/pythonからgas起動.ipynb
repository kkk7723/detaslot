# %%
import requests, json

URL   = "https://script.google.com/macros/s/AKfycbyMK6ATy867meQPm1v1JkGYwUqe8NUdfzLWpBCzDsHrX4B3aTKu9HiCQ9F7pC8H-0m1/exec"
TOKEN = "asfdasfjasdfjadfasfa"

r = requests.post(URL, data={"action":"fetchpachi", "token":TOKEN}, timeout=60)
r.raise_for_status()
print("status:", r.status_code)
print("body  :", r.text)        # {"ok":true} など
try:
    print("json  :", r.json())  # JSONならここで確認
except Exception:
    pass
# Out:
# status: 200
# body  : {"ok":true}
# json  : {'ok': True}
