# %%
import os

folder_path = r"C:\Users\stray\myenv310\iwakuni-tekisasu-p\scripts"

for file_name in os.listdir(folder_path):
    full_path = os.path.join(folder_path, file_name)
    if os.path.isfile(full_path):
        print(file_name)
# Out:
# dbからスプレへ機種名書き込み.ipynb
# dbにwebpURLを書き込み.ipynb
# dbに前日最終ゲーム数書き込み.ipynb
# dbに天井残りゲーム数計算.ipynb
# dbに宵越し最終種別書き込み.ipynb
# dbに宵越し累計ゲーム数書き込み.ipynb
# main.ipynb
# svgnoボナ回転率計算.ipynb
# svg最終回転率計算初当たり.ipynb
# svg計算.ipynb
# クッキー取得.ipynb
# クッキー対応版スクレイピング.ipynb
# スプレから一括ボーダーdb書き込み.ipynb
# スプレ天井設定から店舗別.ipynb
# メール複数条件分岐.ipynb
# 出玉数noボナ回転率計算.ipynb
# 出玉数初当り確率最終回転率.ipynb
# 出玉数時短抜き最終回転率計算.ipynb
# 累計出玉pt計算.ipynb
# 累計通常ゲーム数初当り確率.ipynb
# 累計通常ゲーム数計算時短ぬきv.ipynb
# 重要zip-sshでアップロード.ipynb
# 重要サイト化完璧.ipynb
